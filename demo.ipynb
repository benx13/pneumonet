# %%
from pfe.preprocessing.enhancment.CLAHE import CLAHE
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread("/Users/benx13/Desktop/test.png")
plt.imshow(img)
plt.show()

# %%
clahe = CLAHE.run_cv2(img)
plt.imshow(clahe)
plt.show()
